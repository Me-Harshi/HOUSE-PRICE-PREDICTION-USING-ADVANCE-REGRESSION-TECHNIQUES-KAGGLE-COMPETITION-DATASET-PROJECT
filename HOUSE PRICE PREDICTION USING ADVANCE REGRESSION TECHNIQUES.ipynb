# %% [markdown]
# ![-6265030995124269395_120.jpg](attachment:-6265030995124269395_120.jpg)

# %% [markdown]
# Let's start with some Basic Introduction

# %% [markdown]
# PROBLEM STATEMENT

# %% [markdown]
# Predicting the final Price(dollors) of each home with 79 explanatory variables which are affecting and describing (almost) every aspect of residential homes in Ames, Iowa.Through this dataset,we need to prove that much more influences price negotiations than the number of bedrooms or a white-picket fence.

# %% [markdown]
# # DATA FIELDS

# %% [markdown]
# Data fields
#
# SalePrice : the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# MSSubClass: The building class
#
# MSZoning: The general zoning classification
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access
#
# Alley: Type of alley access
#
# LotShape: General shape of property
#
# LandContour: Flatness of the property
#
# Utilities: Type of utilities available
#
# LotConfig: Lot configuration
#
# LandSlope: Slope of property
#
# Neighborhood: Physical locations within Ames city limits
#
# Condition1: Proximity to main road or railroad
#
# Condition2: Proximity to main road or railroad (if a second is present)
#
# BldgType: Type of dwelling
#
# HouseStyle: Style of dwelling
#
# OverallQual: Overall material and finish quality
#
# OverallCond: Overall condition rating
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date
#
# RoofStyle: Type of roof
#
# RoofMatl: Roof material
#
# Exterior1st: Exterior covering on house
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
# MasVnrType: Masonry veneer type
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Exterior material quality
#
# ExterCond: Present condition of the material on the exterior
#
# Foundation: Type of foundation
#
# BsmtQual: Height of the basement
#
# BsmtCond: General condition of the basement
#
# BsmtExposure: Walkout or garden level basement walls
#
# BsmtFinType1: Quality of basement finished area
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Quality of second finished area (if present)
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
# HeatingQC: Heating quality and condition
#
# CentralAir: Central air conditioning
#
# Electrical: Electrical system
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Number of bedrooms above basement level
#
# Kitchen: Number of kitchens
#
# KitchenQual: Kitchen quality
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality rating Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
# GarageType: Garage location
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
# GarageCond: Garage condition
#
# PavedDrive: Paved driveway
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
# Fence: Fence quality
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold
#
# YrSold: Year Sold
#
# SaleType: Type of sale
#
# SaleCondition: Condition of sale.

# %% [markdown]
# # IMPORT THE DATA

# %% [markdown]
# First import basic required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import io 
# %cd "C:\Users\harsh\Downloads\HOUSE PRICES ANALYSIS"
# Out:
# C:\Users\harsh\Downloads\HOUSE PRICES ANALYSIS

# %% [markdown]
# Load the train and the test data

# %%
train=pd.read_csv("housetrain.csv")

# %%
test=pd.read_csv('housetest.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# Find number of rows and columns in both the datasets

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %% [markdown]
# Adding dependent Variable column to test data for concatenation

# %%
test['SalePrice']=1

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 81)
# (1459, 81)

# %% [markdown]
# Combine Data for preprocessing

# %%
combinedf=pd.concat([train,test],axis=0)
#axis=0 - Row wise Concatenation

# %%
combinedf.shape
# Out:
# (2919, 81)

# %%
combinedf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
pd.set_option('display.max_columns',81,'display.max_rows',2919)

# %%
combinedf.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#As 'Id' column doesn't have any affect on dependent variable ('SalePrice')
combinedf=combinedf.drop('Id',axis=1)

# %%
#observe the variables in the combined dataset
combinedf.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %% [markdown]
# Check for the missing(null) values and datatype of the each column

# %%
combinedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %%
combinedf.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           2909
# MiscFeature      2814
# Alley            2721
# Fence            2348
# FireplaceQu      1420
# LotFrontage       486
# GarageCond        159
# GarageQual        159
# GarageYrBlt       159
# GarageFinish      159
# GarageType        157
# BsmtCond           82
# BsmtExposure       82
# BsmtQual           81
# BsmtFinType2       80
# BsmtFinType1       79
# MasVnrType         24
# MasVnrArea         23
# MSZoning            4
# BsmtHalfBath        2
# Functional          2
# BsmtFullBath        2
# Utilities           2
# BsmtUnfSF           1
# KitchenQual         1
# BsmtFinSF1          1
# SaleType            1
# GarageCars          1
# GarageArea          1
# TotalBsmtSF         1
# Exterior2nd         1
# Exterior1st         1
# Electrical          1
# BsmtFinSF2          1
# TotRmsAbvGrd        0
# Fireplaces          0
# MSSubClass          0
# BedroomAbvGr        0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# ...

# %% [markdown]
# EXPLORATORY DATA   ANALYSIS

# %%
#Observe statistical info
combinedf.describe().transpose()
# Out:
#                 count          mean            std     min     25%      50%  \
# MSSubClass     2919.0     57.137718      42.517628    20.0    20.0     50.0
# LotFrontage    2433.0     69.305795      23.344905    21.0    59.0     68.0
# LotArea        2919.0  10168.114080    7886.996359  1300.0  7478.0   9453.0
# OverallQual    2919.0      6.089072       1.409947     1.0     5.0      6.0
# OverallCond    2919.0      5.564577       1.113131     1.0     5.0      5.0
# YearBuilt      2919.0   1971.312778      30.291442  1872.0  1953.5   1973.0
# YearRemodAdd   2919.0   1984.264474      20.894344  1950.0  1965.0   1993.0
# MasVnrArea     2896.0    102.201312     179.334253     0.0     0.0      0.0
# BsmtFinSF1     2918.0    441.423235     455.610826     0.0     0.0    368.5
# BsmtFinSF2     2918.0     49.582248     169.205611     0.0     0.0      0.0
# BsmtUnfSF      2918.0    560.772104     439.543659     0.0   220.0    467.0
# ...

# %% [markdown]
# Split the data into numerical columns and catogorial columns

# %%
numcols=combinedf.select_dtypes(include=['number'])
catcols=combinedf.select_dtypes(include=['object'])

# %%
print(numcols.shape)
print(catcols.shape)
# Out:
# (2919, 37)
# (2919, 43)

# %%
numcols.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
catcols.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
train.OverallQual.value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
train.OverallCond.value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
train.MSSubClass.value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
print(catcols.shape)
print(numcols.shape)
# Out:
# (2919, 43)
# (2919, 37)

# %% [markdown]
# Check for the correlation between dependent variable and independent variables

# %%
numcols.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.417359 -0.201730     0.033638    -0.065625
# LotFrontage     -0.417359     1.000000  0.489896     0.217645    -0.075508
# LotArea         -0.201730     0.489896  1.000000     0.100541    -0.035617
# OverallQual      0.033638     0.217645  0.100541     1.000000    -0.093847
# OverallCond     -0.065625    -0.075508 -0.035617    -0.093847     1.000000
# YearBuilt        0.034409     0.122811  0.024128     0.597554    -0.368477
# YearRemodAdd     0.043315     0.091557  0.021612     0.571532     0.047654
# MasVnrArea       0.005433     0.221079  0.125596     0.432947    -0.136007
# BsmtFinSF1      -0.064311     0.219408  0.194031     0.281810    -0.050418
# BsmtFinSF2      -0.072530     0.047431  0.084059    -0.042771     0.041501
# BsmtUnfSF       -0.125994     0.113714  0.021362     0.275175    -0.138202
# ...

# %%
#Representation of correlation between top 10 independent variables and dependent using heatmap
c=numcols.corr()
k=10
cols=c.nlargest(k,'SalePrice')['SalePrice'].index
coe=np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
map=sns.heatmap(coe,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# DATA VISUALIZATION

# %%
#This scatter plot showsrelationship between GrLivArea variable and SalePrice variable
plt.scatter(x=train.GrLivArea, y=train.SalePrice,color="orange")

# %%
sns.barplot(x="OverallQual",y="SalePrice",data=train,palette="magma")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
numcols.GarageCars.value_counts()
# Out:
# 2.0    1594
# 1.0     776
# 3.0     374
# 0.0     157
# 4.0      16
# 5.0       1
# Name: GarageCars, dtype: int64

# %%
sns.barplot(x=numcols.GarageCars,y=numcols.SalePrice)
# Out:
# <AxesSubplot:xlabel='GarageCars', ylabel='SalePrice'>

# %%
plt.scatter(x=train.TotalBsmtSF, y=train.SalePrice,color="black")

# %%
sns.barplot(x=numcols.TotRmsAbvGrd,y=numcols.SalePrice)
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd', ylabel='SalePrice'>

# %%
plt.scatter(x=numcols.GarageArea, y=numcols.SalePrice,color="brown")

# %%
plt.scatter(x=numcols.TotalBsmtSF, y=numcols.SalePrice,color="blue")

# %%
plt.scatter(x=train.GarageArea, y=train.SalePrice,color="brown")

# %%
PP=numcols.FullBath
QQ=numcols.SalePrice
sns.barplot(PP,QQ,data=numcols,palette="dark")
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FullBath', ylabel='SalePrice'>

# %%
#Here 'MSSubClass'  is categorical column ,so I am replacing it into catcols(categorical columns)
cat=numcols['MSSubClass']
catcols=pd.concat([catcols,cat],axis=1)

# %%
numcols=numcols.drop('MSSubClass',axis=1)

# %%
catcols.shape
# Out:
# (2919, 44)

# %%
numcols.shape
# Out:
# (2919, 36)

# %%
catcols.MSZoning.value_counts()
# Out:
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: MSZoning, dtype: int64

# %%
catcols.Street.value_counts()
# Out:
# Pave    2907
# Grvl      12
# Name: Street, dtype: int64

# %%
catcols.LotShape.value_counts()
# Out:
# Reg    1859
# IR1     968
# IR2      76
# IR3      16
# Name: LotShape, dtype: int64

# %%
catcols.BsmtQual.value_counts()
# Out:
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: BsmtQual, dtype: int64

# %%
catcols.BsmtCond.value_counts()
# Out:
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: BsmtCond, dtype: int64

# %%
catcols.BsmtExposure.value_counts()
# Out:
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: BsmtExposure, dtype: int64

# %%
catcols.BsmtFinType1.value_counts()
# Out:
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: BsmtFinType1, dtype: int64

# %%
catcols.RoofStyle.value_counts()
# Out:
# Gable      2310
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: RoofStyle, dtype: int64

# %%
sns.barplot(x=train.RoofStyle,y=train.SalePrice,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='RoofStyle', ylabel='SalePrice'>

# %%
#Plotting corelation between missing valued columns
import missingno as msn
msn.heatmap(train)
##A value near -1 means if one variable is present then the other variable is very likely to be missing.
#A value near 0 means there is no dependency between the occurrence of the missing values of two variables.
#A value near 1 means if one variable is present then the other variable is very likely to be present.
#
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DATA PREPROCESSING

# %%
#Check for the null/missing values in numerical columns
numcols.isnull().sum().sort_values(ascending=False)
# Out:
# LotFrontage      486
# GarageYrBlt      159
# MasVnrArea        23
# BsmtHalfBath       2
# BsmtFullBath       2
# TotalBsmtSF        1
# GarageCars         1
# GarageArea         1
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# OpenPorchSF        0
# WoodDeckSF         0
# YrSold             0
# EnclosedPorch      0
# 3SsnPorch          0
# MoSold             0
# Fireplaces         0
# PoolArea           0
# MiscVal            0
# ScreenPorch        0
# HalfBath           0
# TotRmsAbvGrd       0
# KitchenAbvGr       0
# BedroomAbvGr       0
# LotArea            0
# FullBath           0
# GrLivArea          0
# LowQualFinSF       0
# 2ndFlrSF           0
# 1stFlrSF           0
# YearRemodAdd       0
# YearBuilt          0
# OverallCond        0
# OverallQual        0
# SalePrice          0
# dtype: int64

# %% [markdown]
# NULL VALUE TREATMENT ON NUMERICAL COLUMNS

# %%
numcols.LotFrontage=numcols.LotFrontage.fillna(numcols.LotFrontage.median())

# %%
#There are few features in which null values represent that the corresponding feature doesn't exist.
#So I just fill the null values corresponding to that feature with zero.
numcols.MasVnrArea=numcols.MasVnrArea.fillna(0)    
numcols.BsmtHalfBath=numcols.BsmtHalfBath.fillna(0)
numcols.BsmtFullBath=numcols.BsmtFullBath.fillna(0)
numcols.GarageArea=numcols.GarageArea.fillna(0)
numcols.GarageCars=numcols.GarageCars.fillna(0)    
numcols.TotalBsmtSF=numcols.TotalBsmtSF.fillna(0)   
numcols.BsmtUnfSF=numcols.BsmtUnfSF.fillna(0)     
numcols.BsmtFinSF2=numcols.BsmtFinSF2.fillna(0)    
numcols.BsmtFinSF1=numcols.BsmtFinSF1.fillna(0)

# %%
#Check for the null/missing values  in categorical columns
catcols.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           2909
# MiscFeature      2814
# Alley            2721
# Fence            2348
# FireplaceQu      1420
# GarageCond        159
# GarageQual        159
# GarageFinish      159
# GarageType        157
# BsmtCond           82
# BsmtExposure       82
# BsmtQual           81
# BsmtFinType2       80
# BsmtFinType1       79
# MasVnrType         24
# MSZoning            4
# Utilities           2
# Functional          2
# Exterior2nd         1
# Electrical          1
# SaleType            1
# Exterior1st         1
# KitchenQual         1
# RoofStyle           0
# Neighborhood        0
# SaleCondition       0
# ExterQual           0
# LotShape            0
# LandContour         0
# ExterCond           0
# PavedDrive          0
# LotConfig           0
# LandSlope           0
# Condition1          0
# HouseStyle          0
# Condition2          0
# Foundation          0
# RoofMatl            0
# Street              0
# CentralAir          0
# HeatingQC           0
# ...

# %%
catcols.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition', 'MSSubClass'],
#       dtype='object')

# %% [markdown]
# NULL VALUE TREATMENT ON CATEGORICAL COLUMNS

# %%
catcols.PoolQC=catcols.PoolQC.fillna('NA')
catcols.MiscFeature=catcols.MiscFeature.fillna('NA')    
catcols.Alley=catcols.Alley.fillna('NA')          
catcols.Fence=catcols.Fence.fillna('NA')         
catcols.FireplaceQu=catcols.FireplaceQu.fillna('NA')    
catcols.GarageCond=catcols.GarageCond.fillna('NA')    
catcols.GarageQual=catcols.GarageQual.fillna('NA')     
catcols.GarageFinish=catcols.GarageFinish.fillna('NA')   
catcols.GarageType=catcols.GarageType.fillna('NA')     
catcols.BsmtExposure=catcols.BsmtExposure.fillna('NA')     
catcols.BsmtCond=catcols.BsmtCond.fillna('NA')        
catcols.BsmtQual=catcols.BsmtQual.fillna('NA')        
catcols.BsmtFinType2=catcols.BsmtFinType2.fillna('NA')     
catcols.BsmtFinType1=catcols.BsmtFinType1.fillna('NA')
catcols.Exterior2nd=catcols.Exterior2nd.fillna('NA')

# %%
catcols.PoolQC.value_counts()
# Out:
# NA    2909
# Ex       4
# Gd       4
# Fa       2
# Name: PoolQC, dtype: int64

# %%
catcols.MasVnrType.value_counts(dropna=False)
# Out:
# None       1742
# BrkFace     879
# Stone       249
# BrkCmn       25
# NaN          24
# Name: MasVnrType, dtype: int64

# %%
#For this column null value is already represented as None.So I am filling this null values with None
catcols.MasVnrType=catcols.MasVnrType.fillna('None')

# %%
#There are some general properties like (Functional,Utilities,Exterior1st,SaleType,KitchenQual,Electrical) that all houses should have,So NaNs probably mean that the values are not recorded.So I am using "mode" to fill.

# %%
catcols.Functional.value_counts(dropna=False)
# Out:
# Typ     2717
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# NaN        2
# Sev        2
# Name: Functional, dtype: int64

# %%
catcols.Functional=catcols.Functional.fillna('Typ')

# %%
catcols.Utilities.value_counts(dropna=False)
# Out:
# AllPub    2916
# NaN          2
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
catcols.Utilities=catcols.Utilities.fillna('AllPub')

# %%
catcols.Exterior1st.value_counts(dropna=False)
# Out:
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# CBlock        2
# Stone         2
# AsphShn       2
# NaN           1
# ImStucc       1
# Name: Exterior1st, dtype: int64

# %%
catcols.Exterior1st=catcols.Exterior1st.fillna('VinylSd') .Exterior1st=combinedf.Exterior1st.fillna('VinylSd')

# %%
catcols.SaleType.value_counts(dropna=False)
# Out:
# WD       2525
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# NaN         1
# Name: SaleType, dtype: int64

# %%
catcols.SaleType=catcols.SaleType.fillna('VinylSd')

# %%
catcols.KitchenQual.value_counts(dropna=False)
# Out:
# TA     1492
# Gd     1151
# Ex      205
# Fa       70
# NaN       1
# Name: KitchenQual, dtype: int64

# %%
catcols.KitchenQual=catcols.KitchenQual.fillna('TA')

# %%
catcols.Electrical.value_counts(dropna=False)
# Out:
# SBrkr    2671
# FuseA     188
# FuseF      50
# FuseP       8
# NaN         1
# Mix         1
# Name: Electrical, dtype: int64

# %%
catcols.Electrical=catcols.Electrical.fillna('TA')

# %%
catcols.MSZoning.value_counts(dropna=False)
# Out:
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# NaN           4
# Name: MSZoning, dtype: int64

# %%
catcols.MSZoning=catcols.MSZoning.fillna('RL')

# %% [markdown]
# HYPOTHESIS TESTING

# %%
#Test if MSZoning is having significant effect on dependent variable Sale Price

# %%
combinedf.SalePrice.groupby(combinedf.MSZoning).mean()
#means are different
# Out:
# MSZoning
# C (all)     29811.800000
# FV         100079.050360
# RH          80959.384615
# RL          97063.074172
# RM          59863.719565
# Name: SalePrice, dtype: float64

# %%
#NULL:There is no Significant Difference in Sale Price in different MSZoning 
#ALT:There is Significant Difference in Sale Price in different MSZoning

# %%
cc=combinedf[combinedf.MSZoning=='C (all)']
FV=combinedf[combinedf.MSZoning=='FV']
RH=combinedf[combinedf.MSZoning=='RH']
RL=combinedf[combinedf.MSZoning=='RL']
RM=combinedf[combinedf.MSZoning=='RM']

# %%
from scipy.stats import f_oneway

# %%
f_oneway(cc.SalePrice,FV.SalePrice,RH.SalePrice,RL.SalePrice,RM.SalePrice)
#as pvalue=1.5107381728756117e-11 <0.05 ,so reject null
#So There is Significant Difference in Sale Price in different MSZoning
# Out:
# F_onewayResult(statistic=14.28008982167801, pvalue=1.5107381728756117e-11)

# %%
#Test if PoolQC is having significant effect on dependent variable Sale Price

# %%
combinedf.SalePrice.groupby(combinedf.PoolQC).mean()
#means are different
# Out:
# PoolQC
# Ex    245000.50
# Fa    215500.00
# Gd    151492.75
# Name: SalePrice, dtype: float64

# %%
#NULL:There is no Significant Difference in Sale Price due to PoolQC
#ALT:There is Significant Difference in Sale Price due to PoolQC

# %%
Ex=combinedf[combinedf.PoolQC=='Ex']
Fa=combinedf[combinedf.PoolQC=='Fa']
Gd=combinedf[combinedf.PoolQC=='Gd']

# %%
f_oneway(Ex.SalePrice,Fa.SalePrice,Gd.SalePrice)
#as pvalue=0.8609981375636989> 0.05,so fail to reject null
#So There is no Significant Difference in Sale Price due to PoolQC
# Out:
# F_onewayResult(statistic=0.15290889537127883, pvalue=0.8609981375636989)

# %%
#Test if MiscFeature is having significant effect on dependent variable Sale Price

# %%
combinedf.SalePrice.groupby(combinedf.MiscFeature).mean()
#means are different
# Out:
# MiscFeature
# Gar2     68300.600000
# Othr     47000.500000
# Shed     77981.463158
# TenC    250000.000000
# Name: SalePrice, dtype: float64

# %%
#NULL:There is no Significant Difference in Sale Price due to MiscFeature
#ALT:There is Significant Difference in Sale Price due to MiscFeature

# %%
g=combinedf[combinedf.MiscFeature=='Gar2']
o=combinedf[combinedf.MiscFeature=='Othr']
s=combinedf[combinedf.MiscFeature=='Shed']
t=combinedf[combinedf.MiscFeature=='TenC']

# %%
f_oneway(g.SalePrice,o.SalePrice,s.SalePrice,t.SalePrice)
#as pvalue=0.19657545884087269> 0.05,so fail to reject null
# Out:
# F_onewayResult(statistic=1.589601820460441, pvalue=0.19657545884087269)

# %%
#Test if RoofStyle is having significant effect on dependent variable Sale Price

# %%
combinedf.SalePrice.groupby(combinedf.RoofStyle).mean()
#means are different
# Out:
# RoofStyle
# Flat       126548.850000
# Gable       84703.187446
# Gambrel     74455.045455
# Hip        113609.923775
# Mansard    114907.545455
# Shed        90000.600000
# Name: SalePrice, dtype: float64

# %%
#NULL:There is no Significant Difference in Sale Price due to RoofStyle
#ALT:There is Significant Difference in Sale Price due to RoofStyle

# %%
rs=combinedf[combinedf.RoofStyle=='Flat']
ft=combinedf[combinedf.RoofStyle=='Gable']
gg=combinedf[combinedf.RoofStyle=='Gambrel']
gam=combinedf[combinedf.RoofStyle=='Hip']
h=combinedf[combinedf.RoofStyle=='Mansard']
ma=combinedf[combinedf.RoofStyle=='Shed']

# %%
f_oneway(rs.SalePrice,ft.SalePrice,gg.SalePrice,gam.SalePrice,h.SalePrice,ma.SalePrice)
#as pvalue=8.112990583716272e-07< 0.05,so reject null
# Out:
# F_onewayResult(statistic=7.310166597987371, pvalue=8.112990583716272e-07)

# %%
#Test if Street is having significant effect on dependent variable Sale Price

# %%
combinedf.SalePrice.groupby(combinedf.Street).mean()
#means are different
# Out:
# Street
# Grvl    65095.750000
# Pave    90596.923289
# Name: SalePrice, dtype: float64

# %%
combinedf.SalePrice.groupby(combinedf.Street).var()
#variance is different
# Out:
# Street
# Grvl    6.569453e+09
# Pave    1.136068e+10
# Name: SalePrice, dtype: float64

# %%
#NULL:There is no Significant Difference in Sale Price in different streets
#ALT:There is Significant Difference in Sale Price in different streets

# %%
grvl=combinedf[combinedf.Street=='Grvl']
pave=combinedf[combinedf.Street=='Pave']

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(grvl.SalePrice,pave.SalePrice,equal_var = False)
#as pvalue=0.3003723281155972 > 0.05,so fail to reject null
# Out:
# Ttest_indResult(statistic=-1.0860293926936464, pvalue=0.3003723281155972)

# %%
#Test if there is association between Neighborhood and MSZoning

# %%
#NULL:there is association between Neighborhood and MSZoning
#ALT:there is no association between Neighborhood and MSZoning

# %%
pd.crosstab(combinedf.MSZoning,combinedf.Neighborhood)
# Out:
# Neighborhood  Blmngtn  Blueste  BrDale  BrkSide  ClearCr  CollgCr  Crawfor  \
# MSZoning
# C (all)             0        0       0        0        0        0        0
# FV                  0        0       0        0        0        0        0
# RH                  0        0       0        0        0        0        2
# RL                 25        0       0       43       44      253       91
# RM                  3       10      30       65        0       14       10
#
# Neighborhood  Edwards  Gilbert  IDOTRR  MeadowV  Mitchel  NAmes  NPkVill  \
# MSZoning
# C (all)             0        0      22        0        0      0        0
# FV                  0        0       0        0        0      0        0
# RH                  2        0       0        0        0      7        0
# RL                180      165       0        0      104    436       23
# RM                 12        0      68       37        9      0        0
#
# ...

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(combinedf.MSZoning,combinedf.Neighborhood))
#as p value is 0> 0.05, FAIL TO REJECT NULL
# Out:
# (5011.090666861175,
#  0.0,
#  96,
#  array([[2.40137221e-01, 8.57632933e-02, 2.57289880e-01, 9.26243568e-01,
#          3.77358491e-01, 2.28987993e+00, 8.83361921e-01, 1.66380789e+00,
#          1.41509434e+00, 7.71869640e-01, 3.17324185e-01, 9.69125214e-01,
#          3.79931389e+00, 1.97255575e-01, 1.12349914e+00, 6.08919383e-01,
#          1.42367067e+00, 2.04974271e+00, 4.11663808e-01, 1.29502573e+00,
#          1.07204117e+00, 1.56089194e+00, 4.37392796e-01, 6.17495712e-01,
#          2.05831904e-01],
#         [1.33516295e+00, 4.76843911e-01, 1.43053173e+00, 5.14991424e+00,
#          2.09811321e+00, 1.27317324e+01, 4.91149228e+00, 9.25077187e+00,
#          7.86792453e+00, 4.29159520e+00, 1.76432247e+00, 5.38833619e+00,
#          2.11241852e+01, 1.09674099e+00, 6.24665523e+00, 3.38559177e+00,
#          7.91560892e+00, 1.13965695e+01, 2.28885077e+00, 7.20034305e+00,
#          5.96054889e+00, 8.67855918e+00, 2.43190395e+00, 3.43327616e+00,
#          1.14442539e+00],
# ...

# %% [markdown]
# # Label Encoding

# %%
# There are few categorical features whose subclasses are in "rank" order, so they can be label encoded manually.

# %%
catcols.PoolQC.value_counts()
# Out:
# NA    2909
# Ex       4
# Gd       4
# Fa       2
# Name: PoolQC, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.PoolQC).mean()
# Out:
# PoolQC
# Ex    245000.500000
# Fa    215500.000000
# Gd    151492.750000
# NA     90109.808182
# Name: SalePrice, dtype: float64

# %%
catcols.PoolQC = catcols.PoolQC.map({'NA':1, 'Gd': 2, 'Fa':3,'Ex':4})

# %%
catcols.MiscFeature.value_counts()
# Out:
# NA      2814
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Name: MiscFeature, dtype: int64

# %%
catcols.Alley.value_counts()
# Out:
# NA      2721
# Grvl     120
# Pave      78
# Name: Alley, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.Alley).mean()
# Out:
# Alley
# Grvl    50925.200000
# NA      92299.639838
# Pave    88308.474359
# Name: SalePrice, dtype: float64

# %%
catcols.Alley = catcols.Alley.map({'Grvl':0, 'Pave':1, 'NA':2})

# %%
catcols.Fence.value_counts()
# Out:
# NA       2348
# MnPrv     329
# GdPrv     118
# GdWo      112
# MnWw       12
# Name: Fence, dtype: int64

# %%
catcols.FireplaceQu.value_counts()
# Out:
# NA    1420
# Gd     744
# TA     592
# Fa      74
# Po      46
# Ex      43
# Name: FireplaceQu, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.FireplaceQu).mean()
# Out:
# FireplaceQu
# Ex    188491.139535
# Fa     74606.635135
# Gd    115610.083333
# NA     68675.671127
# Po     56419.760870
# TA    108769.815878
# Name: SalePrice, dtype: float64

# %%
catcols.FireplaceQu=catcols.FireplaceQu.map({'Po':0, 'NA':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5})

# %%
catcols.GarageCond.value_counts()
# Out:
# TA    2654
# NA     159
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: GarageCond, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.GarageCond).mean()
# Out:
# GarageCond
# Ex     82667.000000
# Fa     54228.783784
# Gd    107958.400000
# NA     52633.823899
# Po     54250.500000
# TA     93872.574604
# Name: SalePrice, dtype: float64

# %%
catcols.GarageCond = catcols.GarageCond.map({'NA':0, 'Fa':1, 'Po':2, 'Ex':3, 'TA':4, 'Gd':5})

# %%
catcols.GarageQual.value_counts()
# Out:
# TA    2604
# NA     159
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: GarageQual, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.GarageQual).mean()
# Out:
# GarageQual
# Ex    241000.000000
# Fa     47835.459677
# Gd    125919.166667
# NA     52633.823899
# Po     60100.400000
# TA     94393.420891
# Name: SalePrice, dtype: float64

# %%
catcols.GarageQual =catcols.GarageQual.map({'Fa':0, 'NA':1, 'Po':2, 'TA':3, 'Gd':4, 'Ex':5})

# %%
catcols.GarageFinish.value_counts()
# Out:
# Unf    1230
# RFn     811
# Fin     719
# NA      159
# Name: GarageFinish, dtype: int64

# %%
catcols.BsmtExposure.value_counts()
# Out:
# No    1904
# Av     418
# Gd     276
# Mn     239
# NA      82
# Name: BsmtExposure, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.BsmtExposure).mean()
# Out:
# BsmtExposure
# Av    109254.528708
# Gd    125110.782609
# Mn     91958.769874
# NA     50020.743902
# No     82913.649685
# Name: SalePrice, dtype: float64

# %%
catcols.BsmtExposure =catcols.BsmtExposure.map({'NA':0, 'No':1, 'Mn':2, 'Av':3, 'Gd':4})

# %%
combinedf.BsmtFinType2.value_counts(dropna=False)
# Out:
# Unf    2493
# Rec     105
# LwQ      87
# NaN      80
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.BsmtFinType2).mean()
# Out:
# BsmtFinType2
# ALQ    76710.250000
# BLQ    73328.941176
# GLQ    74522.647059
# LwQ    86905.643678
# NA     52414.987500
# Rec    84815.009524
# Unf    93051.651825
# Name: SalePrice, dtype: float64

# %%
catcols.BsmtFinType2 =catcols.BsmtFinType2.map({'NA':0, 'BLQ':1, 'GLQ':2, 'ALQ':3,'Rec':4,'LwQ':5,'Unf':6})

# %%
catcols.BsmtFinType1.value_counts()
# Out:
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# NA      79
# Name: BsmtFinType1, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.BsmtFinType1).mean()
# Out:
# BsmtFinType1
# ALQ     82858.470862
# BLQ     82249.747212
# GLQ    115905.024735
# LwQ     72968.701299
# NA      49483.531646
# Rec     67834.809028
# Unf     86238.271445
# Name: SalePrice, dtype: float64

# %%
catcols.BsmtFinType1 =catcols.BsmtFinType1.map({'NA':0, 'Rec':1,'LwQ':2,'BLQ':3, 'ALQ':4, 'Unf':5,'GLQ':6})

# %%
catcols.Utilities.value_counts()
# Out:
# AllPub    2918
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.Utilities).mean()
# Out:
# Utilities
# AllPub     90475.97841
# NoSeWa    137500.00000
# Name: SalePrice, dtype: float64

# %%
catcols.Utilities = catcols.Utilities.map({'AllPub':0,'NoSeWa':1})

# %%
combinedf.PavedDrive.value_counts(dropna=False)
# Out:
# Y    2641
# N     216
# P      62
# Name: PavedDrive, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.PavedDrive).mean()
# Out:
# PavedDrive
# N    47933.550926
# P    64031.161290
# Y    94594.027262
# Name: SalePrice, dtype: float64

# %%
catcols.PavedDrive =catcols.PavedDrive.map({'N':0, 'P':1, 'Y':2})

# %%
catcols.KitchenQual.value_counts(dropna=False)
# Out:
# TA    1493
# Gd    1151
# Ex     205
# Fa      70
# Name: KitchenQual, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.KitchenQual).mean()
# Out:
# KitchenQual
# Ex    160271.082927
# Fa     58815.342857
# Gd    107993.531712
# TA     68903.686537
# Name: SalePrice, dtype: float64

# %%
catcols.KitchenQual =catcols.KitchenQual.map({'Po':0,'Fa':1, 'TA':2, 'Gd':3, 'Ex':4})

# %%
catcols.LandSlope.value_counts(dropna=False)
# Out:
# Gtl    2778
# Mod     125
# Sev      16
# Name: LandSlope, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.LandSlope).mean()
# Out:
# LandSlope
# Gtl     89525.447444
# Mod    102302.232000
# Sev    166058.312500
# Name: SalePrice, dtype: float64

# %%
catcols.LandSlope =catcols.LandSlope.map({'Gtl':1, 'Mod':2, 'Sev':3})

# %%
catcols.Street.value_counts(dropna=False)
# Out:
# Pave    2907
# Grvl      12
# Name: Street, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.Street).mean()
# Out:
# Street
# Grvl    65095.750000
# Pave    90596.923289
# Name: SalePrice, dtype: float64

# %%
catcols.Street =catcols.Street.map({'Grvl':0, 'Pave':1})

# %%
catcols.HeatingQC.value_counts(dropna=False)
# Out:
# Ex    1493
# TA     857
# Gd     474
# Fa      92
# Po       3
# Name: HeatingQC, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.HeatingQC).mean()
# Out:
# HeatingQC
# Ex    106666.004019
# Fa     66001.065217
# Gd     79753.630802
# Po     29000.666667
# TA     71098.879813
# Name: SalePrice, dtype: float64

# %%
catcols.HeatingQC =catcols.HeatingQC.map({'Po':0, 'Fa':1, 'TA':2, 'Gd':3, 'Ex':4})

# %%
catcols.BsmtCond.value_counts()
# Out:
# TA    2606
# Gd     122
# Fa     104
# NA      82
# Po       5
# Name: BsmtCond, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.BsmtCond).mean()
# Out:
# BsmtCond
# Fa     52706.615385
# Gd    113803.696721
# NA     47673.195122
# Po     25600.600000
# TA     92380.529931
# Name: SalePrice, dtype: float64

# %%
catcols.BsmtCond =catcols.BsmtCond.map({'Po':0, 'NA':1, 'Fa':2, 'TA':3, 'Gd':4})

# %%
catcols.BsmtQual.value_counts(dropna=False)
# Out:
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# NA      81
# Name: BsmtQual, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.BsmtQual).mean()
# Out:
# BsmtQual
# Ex    153380.244186
# Fa     46014.477273
# Gd    103607.999173
# NA     48261.740741
# TA     71203.239283
# Name: SalePrice, dtype: float64

# %%
catcols.BsmtQual =catcols.BsmtQual.map({'Fa':0, 'NA':1, 'TA':2, 'Gd':3, 'Ex':4})

# %%
catcols.Functional.value_counts(dropna=False)
# Out:
# Typ     2719
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: Functional, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.Functional).mean()
# Out:
# Functional
# Maj1    113435.736842
# Maj2     47667.111111
# Min1     69815.138462
# Min2     70060.257143
# Mod      72169.142857
# Sev      64500.500000
# Typ      91748.804340
# Name: SalePrice, dtype: float64

# %%
catcols.Functional =catcols.Functional.map({'Maj2':0,'Sev':1,'Min1':2,'Min2':3,'Mod':4,'Typ':5,'Maj1':6})

# %%
catcols.ExterCond.value_counts(dropna=False)
# Out:
# TA    2538
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: ExterCond, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.ExterCond).mean()
# Out:
# ExterCond
# Ex    50334.083333
# Fa    42876.164179
# Gd    82472.234114
# Po    25500.666667
# TA    92960.596139
# Name: SalePrice, dtype: float64

# %%
catcols.ExterCond = catcols.ExterCond.map({'Po':0, 'Fa':1, 'Ex':2, 'Gd':3, 'TA':4})

# %%
catcols.ExterQual.value_counts(dropna=False)
# Out:
# TA    1798
# Gd     979
# Ex     107
# Fa      35
# Name: ExterQual, dtype: int64

# %%
combinedf.SalePrice.groupby(catcols.ExterQual).mean()
# Out:
# ExterQual
# Ex    178531.074766
# Fa     35194.685714
# Gd    115462.353422
# TA     72733.104561
# Name: SalePrice, dtype: float64

# %%
catcols.ExterQual =catcols.ExterQual.map({'Fa':0, 'TA':1, 'Gd':2, 'Ex':'3'})

# %%
numincatcols=catcols[['PoolQC','Alley','FireplaceQu','GarageCond','GarageQual','BsmtExposure','BsmtFinType1','BsmtFinType2','Utilities','PavedDrive','Functional','KitchenQual','LandSlope','Street','HeatingQC','BsmtCond','BsmtQual','ExterCond','ExterQual']]

# %%
catcols=catcols.drop(['PoolQC','Alley','FireplaceQu','GarageCond','GarageQual','BsmtExposure','BsmtFinType1','BsmtFinType2','Utilities','PavedDrive','Functional','KitchenQual','LandSlope','Street','HeatingQC','BsmtCond','BsmtQual','ExterCond','ExterQual'],axis=1)

# %%
print(catcols.shape)
print(numincatcols.shape)
print(numcols.shape)
# Out:
# (2919, 25)
# (2919, 19)
# (2919, 36)

# %%
numincatcols.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          0
# Functional      0
# ExterCond       0
# BsmtQual        0
# BsmtCond        0
# HeatingQC       0
# Street          0
# LandSlope       0
# KitchenQual     0
# PavedDrive      0
# Alley           0
# Utilities       0
# BsmtFinType2    0
# BsmtFinType1    0
# BsmtExposure    0
# GarageQual      0
# GarageCond      0
# FireplaceQu     0
# ExterQual       0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Extracting Useful columns from existing Time variables.

# %%
numcols['Age']=numcols.YrSold-numcols.YearBuilt

# %%
numcols['AgeofRemod']=numcols.YrSold - numcols.YearRemodAdd

# %%
numcols['AgeofGarage']=numcols.YrSold -numcols.GarageYrBlt

# %%
# Some of the values in Age,AgeofRemod,AgeofGarage are negative because the work was done after the house 
# was sold. In that case, I changed them to zero to avoid negative ages.

# %%
numcols.Age = numcols.Age.map(lambda a: 0 if a < 0 else a)

# %%
numcols.AgeofRemod =numcols.AgeofRemod.map(lambda a: 0 if a < 0 else a)

# %%
numcols.AgeofGarage =numcols.AgeofGarage.map(lambda a: 0 if a < 0 else a)

# %%
# drop the original time variables 
numcols=numcols.drop(['YrSold','YearBuilt','YearRemodAdd','GarageYrBlt'],axis=1)

# %%
#rechecking for the null values in numerical columns after adding new columns and fill null values if any.

# %%
numcols.isnull().sum().sort_values(ascending=False)
# Out:
# AgeofGarage      159
# 3SsnPorch          0
# Fireplaces         0
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# ScreenPorch        0
# KitchenAbvGr       0
# PoolArea           0
# MiscVal            0
# MoSold             0
# SalePrice          0
# Age                0
# AgeofRemod         0
# TotRmsAbvGrd       0
# LotFrontage        0
# LotArea            0
# TotalBsmtSF        0
# OverallQual        0
# OverallCond        0
# MasVnrArea         0
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# 1stFlrSF           0
# HalfBath           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# BedroomAbvGr       0
# dtype: int64

# %%
numcols.AgeofGarage=numcols.AgeofGarage.fillna(0)

# %%
#rechecking for the null values in categorical columns once again and fill null values if any.

# %%
catcols.isnull().sum().sort_values(ascending=False)
# Out:
# MSZoning         0
# MasVnrType       0
# SaleCondition    0
# SaleType         0
# MiscFeature      0
# Fence            0
# GarageFinish     0
# GarageType       0
# Electrical       0
# CentralAir       0
# Heating          0
# Foundation       0
# Exterior2nd      0
# LotShape         0
# Exterior1st      0
# RoofMatl         0
# RoofStyle        0
# HouseStyle       0
# BldgType         0
# Condition2       0
# Condition1       0
# Neighborhood     0
# LotConfig        0
# LandContour      0
# MSSubClass       0
# dtype: int64

# %%
#create dummy variables and drop last column of dummies to avoid dummy variable trap
catdummy=pd.get_dummies(catcols)

# %%
#combine all numcols,numincatcols,catdummy
df=pd.concat([numcols,numincatcols,catdummy],axis=1)

# %%
df=df.astype(float)

# %%
df.dtypes
# Out:
# LotFrontage              float64
# LotArea                  float64
# OverallQual              float64
# OverallCond              float64
# MasVnrArea               float64
# BsmtFinSF1               float64
# BsmtFinSF2               float64
# BsmtUnfSF                float64
# TotalBsmtSF              float64
# 1stFlrSF                 float64
# 2ndFlrSF                 float64
# LowQualFinSF             float64
# GrLivArea                float64
# BsmtFullBath             float64
# BsmtHalfBath             float64
# FullBath                 float64
# HalfBath                 float64
# BedroomAbvGr             float64
# KitchenAbvGr             float64
# TotRmsAbvGrd             float64
# Fireplaces               float64
# GarageCars               float64
# GarageArea               float64
# WoodDeckSF               float64
# OpenPorchSF              float64
# EnclosedPorch            float64
# 3SsnPorch                float64
# ScreenPorch              float64
# ...

# %%
df.shape
# Out:
# (2919, 235)

# %% [markdown]
# SPLITIING BACK TO TRAIN AND TEST DATASET

# %%
traindf=df[df.SalePrice!=1]
testdf=df[df.SalePrice==1]
ytrain=traindf.SalePrice

# %%
traindf=traindf.drop('SalePrice',axis=1)
testdf=testdf.drop('SalePrice',axis=1)

# %%
print(traindf.shape)
print(testdf.shape)
# Out:
# (1460, 234)
# (1459, 234)

# %%
#RECHECKING FOR NULL VALUES IN TEST DATA
testdf.isnull().sum()
# Out:
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
# MasVnrArea               0
# BsmtFinSF1               0
# BsmtFinSF2               0
# BsmtUnfSF                0
# TotalBsmtSF              0
# 1stFlrSF                 0
# 2ndFlrSF                 0
# LowQualFinSF             0
# GrLivArea                0
# BsmtFullBath             0
# BsmtHalfBath             0
# FullBath                 0
# HalfBath                 0
# BedroomAbvGr             0
# KitchenAbvGr             0
# TotRmsAbvGrd             0
# Fireplaces               0
# GarageCars               0
# GarageArea               0
# WoodDeckSF               0
# OpenPorchSF              0
# EnclosedPorch            0
# 3SsnPorch                0
# ScreenPorch              0
# PoolArea                 0
# MiscVal                  0
# MoSold                   0
# Age                      0
# AgeofRemod               0
# AgeofGarage              0
# ...

# %% [markdown]
# # Feature Selection

# %%
#using ExtraTreesRegressor as estimator for model selection
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.feature_selection import SelectFromModel

# %%
xtr=ExtraTreesRegressor(n_estimators=50)

# %%
xtr=xtr.fit(traindf,ytrain)

# %%
traindf.isnull().sum()
# Out:
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
# MasVnrArea               0
# BsmtFinSF1               0
# BsmtFinSF2               0
# BsmtUnfSF                0
# TotalBsmtSF              0
# 1stFlrSF                 0
# 2ndFlrSF                 0
# LowQualFinSF             0
# GrLivArea                0
# BsmtFullBath             0
# BsmtHalfBath             0
# FullBath                 0
# HalfBath                 0
# BedroomAbvGr             0
# KitchenAbvGr             0
# TotRmsAbvGrd             0
# Fireplaces               0
# GarageCars               0
# GarageArea               0
# WoodDeckSF               0
# OpenPorchSF              0
# EnclosedPorch            0
# 3SsnPorch                0
# ScreenPorch              0
# PoolArea                 0
# MiscVal                  0
# MoSold                   0
# Age                      0
# AgeofRemod               0
# AgeofGarage              0
# ...

# %%
xtr.feature_importances_
# Out:
# array([2.17942385e-03, 5.70512542e-03, 2.63375024e-01, 2.76700585e-03,
#        4.56339082e-03, 1.22554787e-02, 1.52248611e-03, 3.16792942e-03,
#        1.77136958e-02, 1.69595604e-02, 1.74956899e-02, 2.08282617e-04,
#        5.93865206e-02, 4.99418209e-03, 6.53192931e-04, 2.49887191e-02,
#        3.06388362e-03, 4.81387637e-03, 6.11205207e-04, 1.40617923e-02,
#        8.31274295e-03, 9.53653941e-02, 2.13902587e-02, 3.05422643e-03,
#        2.78752736e-03, 1.06701579e-03, 6.64028363e-04, 1.86125597e-03,
#        1.65711474e-04, 1.19589083e-04, 2.73899641e-03, 4.59140980e-03,
#        4.99704871e-03, 2.06641328e-03, 3.12116439e-04, 9.04081536e-04,
#        1.50501189e-02, 5.51965205e-04, 9.01020604e-04, 4.65924726e-03,
#        1.72450581e-03, 7.75653608e-04, 3.91170086e-06, 4.58742403e-04,
#        6.51251767e-04, 9.52041318e-02, 1.49565168e-03, 4.73446082e-06,
#        1.78051660e-03, 9.11118488e-04, 4.75949638e-02, 7.59647904e-04,
# ...

# %%
model = SelectFromModel(xtr, prefit=True)

# %%
new=model.transform(traindf)

# %%
plt.figure(figsize=(20,10))
feat_importances = pd.Series(xtr.feature_importances_,index=traindf.columns)
feat_importances.nlargest(30).plot(kind='barh')
plt.show()

# %% [markdown]
# # FIT MODEL

# %% [markdown]
# Multiple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
regmodel=reg.fit(traindf,ytrain)

# %%
regmodel.score(traindf,ytrain)
# Out:
# 0.9189338132581165

# %%
regpredict=regmodel.predict(traindf)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(regpredict,ytrain))
# Out:
# 22611.22069242405

# %%
predicttest=regmodel.predict(testdf)

# %%
pd.DataFrame(predicttest).to_csv("pricepredict_reg.csv")

# %%
#applying multiple Linear Regression model on test data,I got RMSE error-0.17301

# %% [markdown]
# Multiple Linear Regression with Lasso Regularization

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso(alpha=0.0009,max_iter=80000)

# %%
lassomodel=lasso.fit(traindf,ytrain)
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86624102493.75891, tolerance: 920791133.4609977
#   model = cd_fast.enet_coordinate_descent(

# %%
lassomodel.score(traindf,ytrain)
# Out:
# 0.9189338132470746

# %%
lassopred=lassomodel.predict(traindf)

# %%
np.sqrt(mean_squared_error(lassopred,ytrain))
# Out:
# 22611.22069396397

# %%
lassopredicttest=lassomodel.predict(testdf)

# %%
pd.DataFrame(lassopredicttest).to_csv("pricepredict_lasso.csv")

# %%
#applying multiple Linear Regression model using lasso regularization on test data,I got RMSE error- 0.17300

# %% [markdown]
# Multiple Linear Regression with Ridge Regularization

# %%
from sklearn.linear_model import Ridge

# %%
ridge=Ridge()

# %%
ridgemodel=ridge.fit(traindf,ytrain)

# %%
ridgemodel.score(traindf,ytrain)
# Out:
# 0.9085392476976041

# %%
rpred=ridgemodel.predict(traindf)

# %%
np.sqrt(mean_squared_error(rpred,ytrain))
# Out:
# 24017.15280020115

# %%
ridgepredicttest=ridgemodel.predict(testdf)

# %%
pd.DataFrame(ridgepredicttest).to_csv("pricepredict_ridge.csv")

# %%
#applying multiple Linear Regression model using ridge regularization on test data,I got RMSE error- 0.17531

# %% [markdown]
# Multiple Linear Regression using Elasticnet

# %%
from sklearn.linear_model import ElasticNet

# %%
en=ElasticNet()

# %%
enmodel=en.fit(traindf,ytrain)
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 839304866055.2451, tolerance: 920791133.4609977
#   model = cd_fast.enet_coordinate_descent(

# %%
enmodel.score(traindf,ytrain)
# Out:
# 0.8321424892100686

# %%
enpred=enmodel.predict(traindf)

# %%
np.sqrt(mean_squared_error(enpred,ytrain))
# Out:
# 32536.776623001337

# %%
elasticnetpredicttest=enmodel.predict(testdf)

# %%
pd.DataFrame(elasticnetpredicttest).to_csv("pricepredict_elasticnet.csv")

# %%
#applying multiple Linear Regression model using elastic net regularization on test data,I got RMSE error- 0.15568

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree=DecisionTreeRegressor(max_depth=8)

# %%
treemodel=tree.fit(traindf,ytrain)

# %%
treemodel.score(traindf,ytrain)
# Out:
# 0.9593267355499678

# %%
treepredict=treemodel.predict(traindf)

# %%
np.sqrt(mean_squared_error(treepredict,ytrain))
# Out:
# 16016.169328599028

# %%
decisiontreepredicttest=treemodel.predict(testdf)

# %%
pd.DataFrame(decisiontreepredicttest).to_csv("pricepredict_decisiontreeee.csv")

# %%
#applying decision tree model on test data I got RMSE error-0.20474

# %% [markdown]
# Ensemble Techniques:Bagging:
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor(n_estimators=3000) # 3000 Decision Trees

# %%
RFmodel=RF.fit(traindf,ytrain)

# %%
RFmodel.score(traindf,ytrain)
# Out:
# 0.9816959092577933

# %%
RFpredict=RFmodel.predict(traindf)

# %%
np.sqrt(mean_squared_error(RFpredict,ytrain))
# Out:
# 10744.302236913614

# %%
randompredicttest=RFmodel.predict(testdf)

# %%
pd.DataFrame(randompredicttest).to_csv("pricepredict_RF.csv")

# %%
#applying random forest regression  model on test data I got RMSE error-0.14449

# %%
Ensemble Technique:Boosting:Adaboost Regressor

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm=GradientBoostingRegressor(n_estimators=3000)

# %%
gbmmodel=gbm.fit(traindf,ytrain)

# %%
gbmmodel.score(traindf,ytrain)
# Out:
# 0.9999627843173309

# %%
gbmpredict=gbmmodel.predict(traindf)

# %%
np.sqrt(mean_squared_error(gbmpredict,ytrain))
# Out:
# 484.47027014422764

# %%
gbmpred=gbmmodel.predict(testdf)

# %%
pd.DataFrame(gbmpred).to_csv("pricepredict_gbm.csv")

# %%
#applying gradient boosting model on test data I got RMSE error-0.13564

# %% [markdown]
# Xgboost model

# %%
import xgboost as xgb

# %%
xgb_model=xgb.XGBRegressor()

# %%
best_xgb=xgb.XGBRegressor(n_estimators=1000,learning_rate=0.05,max_depth=7,gamma=0,colsample_bytree=0.5,subsample=0.7,min_child_weight=1)

# %%
best_xgb_model=best_xgb.fit(traindf,ytrain)

# %%
predictxg=best_xgb_model.predict(traindf)

# %%
np.sqrt(mean_squared_error(predictxg,ytrain))
# Out:
# 160.91455403724257

# %%
xgbpredict=best_xgb_model.predict(testdf)

# %%
pd.DataFrame(xgbpredict).to_csv('pricepredict_xgbng.csv')

# %%
#applying Xgboost model on test data I got RMSE error-0.12670 with rank 1125
#so far this is the best model with mininum RMSE error that I have got.

# %%
residual=ytrain-predictxg

# %% [markdown]
# # Model Evaluation

# %%
#Residual plot for analysis
sns.scatterplot(residual,predictxg,color='black')
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SalePrice'>

# %%
#plot histogram to check distribution of residuals.
sns.histplot(residual,bins=100)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
from sklearn import metrics

# %%
#Evaluation metrics
print('MAE:', metrics.mean_absolute_error(predictxg,ytrain))
print('MSE:', metrics.mean_squared_error(predictxg,ytrain))
print('RMSE:', np.sqrt(metrics.mean_squared_error(predictxg,ytrain)))
# Out:
# MAE: 109.07754708904109
# MSE: 25893.493701004656
# RMSE: 160.91455403724257

# %% [markdown]
# ![new%20end%20pic.jpg](attachment:new%20end%20pic.jpg)
